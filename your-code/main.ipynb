# %% [markdown]
# # Understanding Descriptive Statistics
#
# Import the necessary libraries here:

# %%
# Libraries
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Challenge 1
# #### 1.- Define a function that simulates rolling a dice 10 times. Save the information in a dataframe.
# **Hint**: you can use the *choices* function from module *random* to help you with the simulation.

# %%
# your code here  ()=
def rolling_dice_10():
  throw_dices = [random.randint(1,6) for i in range(10)]
  return throw_dices

# %%
rolling_dice_10()
result = rolling_dice_10()

# %%
result
# Out:
# [5, 4, 2, 6, 6, 2, 4, 2, 6, 3]

# %%
df_result = pd.DataFrame({'results':result})
df_result
# Out:
#    results
# 0        5
# 1        4
# 2        2
# 3        6
# 4        6
# 5        2
# 6        4
# 7        2
# 8        6
# 9        3

# %% [markdown]
# #### 2.- Plot the results sorted by value.

# %%
# your code here

df_sorted = df_result.sort_values('results')
df_sorted
# Out:
#    results
# 2        2
# 5        2
# 7        2
# 9        3
# 1        4
# 6        4
# 0        5
# 3        6
# 4        6
# 8        6

# %%
df_sorted.plot(kind="bar", y="results")
# Out:
# <Axes: >

# %% [markdown]
# #### 3.- Calculate the frequency distribution and plot it. What is the relation between this plot and the plot above? Describe it with words.

# %%
# your code here

df_sorted_counted = df_sorted.value_counts()

df_sorted_counted.plot(kind="bar", y="results")
# Out:
# <Axes: xlabel='results'>

# %%
"""
your comments here
"""

# %% [markdown]
# ## Challenge 2
# Now, using the dice results obtained in *challenge 1*, your are going to define some functions that will help you calculate the mean of your data in two different ways, the median and the four quartiles.
#
# #### 1.- Define a function that computes the mean by summing all the observations and dividing by the total number of observations. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
#
def mean (result):
  count = sum(result)/len(result)
  return count

#def median(result):
#  if result %2 = 1

#  m = len(result)/2

# %%
mean(result)
# Out:
# 4.0

# %% [markdown]
# #### 2.- First, calculate the frequency distribution. Then, calculate the mean using the values of the frequency distribution you've just computed. You are not allowed to use any methods or functions that directly calculate the mean value.

# %%
# your code here
f_distr = df_result.value_counts()

f_distr
# Out:
# results
# 2          3
# 6          3
# 4          2
# 3          1
# 5          1
# dtype: int64

# %%
mean(f_distr)
# Out:
# 2.0

# %% [markdown]
# #### 3.- Define a function to calculate the median. You are not allowed to use any methods or functions that directly calculate the median value.
# **Hint**: you might need to define two computation cases depending on the number of observations used to calculate the median.

# %%
# your code here
def median(results):
  sorted_reults = np.sort(results)
  size = len(sorted_reultsresults)

  if size %2 == 0:
    middle1 = sorted_numbers[size // 2 - 1]
    middle2 = sorted_numbers[size // 2]
    median_value = (middle1 + middle2) / 2
  else:
    median_value = sorted_numbers[size // 2]

  return median_value

# %% [markdown]
# #### 4.- Define a function to calculate the four quartiles. You can use the function you defined above to compute the median but you are not allowed to use any methods or functions that directly calculate the quartiles.

# %%
# a function to calculate the four quartiles

def quartiles(results):
  sorted_reults = np.sort(results)
  size = len(sorted_reultsresults)
  q2 = median

  if size %2 == 0:
    first_half = sorted_reults
    sec_half = sorted_reults

  else:


  return

# %% [markdown]
# ## Challenge 3
# Read the csv `roll_the_dice_hundred.csv` from the `data` folder.
# #### 1.- Sort the values and plot them. What do you see?

# %%
# Read the csv roll_the_dice_hundred.csv
roll_h = pd.read_csv('/content/roll_the_dice_hundred.csv')

# %%
roll_h_s = roll_h.sort_values(by = 'value')

# %%
roll_h_s
# Out:
#     Unnamed: 0  roll  value
# 0            0     0      1
# 47          47    47      1
# 56          56    56      1
# 9            9     9      1
# 73          73    73      1
# ..         ...   ...    ...
# 17          17    17      6
# 11          11    11      6
# 24          24    24      6
# 21          21    21      6
# 99          99    99      6
#
# [100 rows x 3 columns]

# %%
x = roll_h_s['roll']

y= roll_h_s ['value']

plt.scatter(x,y)
plt.show ()

# %% [markdown]
# #### 2.- Using the functions you defined in *challenge 2*, calculate the mean value of the hundred dice rolls.

# %%
# your code here

mean(roll_h['value'])
# Out:
# 3.74

# %% [markdown]
# #### 3.- Now, calculate the frequency distribution.

# %%
# your code here

frequency_values = roll_h.value_counts('value')

# %% [markdown]
# #### 4.- Plot the histogram. What do you see (shape, values...) ? How can you connect the mean value to the histogram?

# %%
# your code here

frequency_values.plot(kind='bar', y='count')
plt.show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### 5.- Read the `roll_the_dice_thousand.csv` from the `data` folder. Plot the frequency distribution as you did before. Has anything changed? Why do you think it changed?

# %%
# Read the roll_the_dice_thousand.csv


roll_t = pd.read_csv('/content/roll_the_dice_thousand.csv')

roll_t
# Out:
#      Unnamed: 0  roll  value
# 0             0     0      5
# 1             1     1      6
# 2             2     2      1
# 3             3     3      6
# 4             4     4      5
# ..          ...   ...    ...
# 995         995   995      1
# 996         996   996      4
# 997         997   997      4
# 998         998   998      3
# 999         999   999      6
#
# [1000 rows x 3 columns]

# %%
#Plot the frequency distribution

frequency_values_t = roll_t.value_counts('value')

# %%
frequency_values_t.plot(kind='bar', y='count')
plt.show()

# %% [markdown]
# ## Challenge 4
# In the `data` folder of this repository you will find three different files with the prefix `ages_population`. These files contain information about a poll answered by a thousand people regarding their age. Each file corresponds to the poll answers in different neighbourhoods of Barcelona.
#
# #### 1.- Read the file `ages_population.csv`. Calculate the frequency distribution and plot it as we did during the lesson. Try to guess the range in which the mean and the standard deviation will be by looking at the plot.

# %%
# your code here

ages = pd.read_csv('/content/ages_population.csv')
ages
# Out:
#      observation
# 0           68.0
# 1           12.0
# 2           45.0
# 3           38.0
# 4           49.0
# ..           ...
# 995         27.0
# 996         47.0
# 997         53.0
# 998         33.0
# 999         31.0
#
# [1000 rows x 1 columns]

# %%
freq_ages = ages['observation'].value_counts()
df_freq_ages = pd.DataFrame(freq_ages)

df_freq_ages
# Out:
#       observation
# 39.0           45
# 41.0           36
# 30.0           34
# 35.0           33
# 43.0           32
# ...           ...
# 73.0            1
# 82.0            1
# 70.0            1
# 71.0            1
# 69.0            1
#
# [72 rows x 1 columns]

# %%
plt.bar()
plt.xlabel('Age')
plt.ylabel('freq_ages')
plt.show()

# dúvida

# %% [markdown]
# #### 2.- Calculate the exact mean and standard deviation and compare them with your guesses. Do they fall inside the ranges you guessed?

# %%
#

ages["observation"].mean()
# Out:
# 36.56

# %%
ages["observation"].std()
# Out:
# 12.81649962597677

# %% [markdown]
# #### 3.- Now read the file `ages_population2.csv` . Calculate the frequency distribution and plot it.

# %%
ages2 = pd.read_csv('/content/ages_population2.csv')
ages2
# Out:
#      observation
# 0           25.0
# 1           31.0
# 2           29.0
# 3           31.0
# 4           29.0
# ..           ...
# 995         26.0
# 996         22.0
# 997         21.0
# 998         19.0
# 999         28.0
#
# [1000 rows x 1 columns]

# %% [markdown]
# ####  4.- What do you see? Is there any difference with the frequency distribution in step 1?

# %%
"""
your comments here
"""

# %% [markdown]
# #### 5.- Calculate the mean and standard deviation. Compare the results with the mean and standard deviation in step 2. What do you think?

# %%
ages2["observation"].std()
# Out:
# 2.9698139326891835

# %%
ages2["observation"].mean()
# Out:
# 27.155

# %%
Values tend to be close to the mean

# %% [markdown]
# ## Challenge 5
# Now is the turn of `ages_population3.csv`.
#
# #### 1.- Read the file `ages_population3.csv`. Calculate the frequency distribution and plot it.

# %%
# your code here

ages3 = pd.read_csv('/content/ages_population3.csv')
ages3
# Out:
#      observation
# 0           21.0
# 1           21.0
# 2           24.0
# 3           31.0
# 4           54.0
# ..           ...
# 995         16.0
# 996         55.0
# 997         30.0
# 998         35.0
# 999         43.0
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### 2.- Calculate the mean and standard deviation. Compare the results with the plot in step 1. What is happening?

# %%
# your code here
ages3["observation"].mean()
# Out:
# 41.989

# %%
ages3["observation"].std()
# Out:
# 16.14470595986593

# %%
"""
your comments here
"""

# %% [markdown]
# #### 3.- Calculate the four quartiles. Use the results to explain your reasoning for question in step 2. How much of a difference is there between the median and the mean?

# %%
q1 = ages3["observation"].quantile(0.25)
q2 = ages3["observation"].quantile(0.5)
q3 = ages3["observation"].quantile(0.75)
print(q1, q2, q3)
# Out:
# 30.0 40.0 53.0

# %%
"""
your comments here
"""

# %% [markdown]
# #### 4.- Calculate other percentiles that might be useful to give more arguments to your reasoning.

# %%
q01 = np.quantile(ages3,0.15)
print(f"the 0.15 quartile is {q1}")

q02 = np.quantile(ages3,0.3)
print(f"the 0.3 quartile is {q2}")
# Out:
# the 0.15 quartile is 30.0
# the 0.3 quartile is 40.0

# %%
"""
your comments here
"""

# %% [markdown]
# ## Bonus challenge
# Compare the information about the three neighbourhoods. Prepare a report about the three of them. Remember to find out which are their similarities and their differences backing your arguments in basic statistics.

# %%
# your code here

# %%
"""
your comments here
"""
